# %%
import glob, json, os
from PIL import Image
from tqdm import tqdm_notebook
import numpy as np
from sklearn.preprocessing import normalize
import matplotlib.pyplot as plt

img_paths = glob.glob('./ai_challenger_caption_validation_20170910/caption_validation_images_20170910/*.jpg')
img_paths.sort()

img_paths = img_paths[:3000]
img_paths[:2]
# Out:
# ['./ai_challenger_caption_validation_20170910/caption_validation_images_20170910\\0003a0755539c426ecfc7ed79bc74aeea6be740b.jpg',
#  './ai_challenger_caption_validation_20170910/caption_validation_images_20170910\\000420107b8abee7c2f08bb21e4444a9d00c9323.jpg']

# %%
validation_annotations = json.load(
    open('./ai_challenger_caption_validation_20170910/caption_validation_annotations_20170910.json')
)

validation_annotations[:2]
# Out:
# [{'url': 'http://img5.cache.netease.com/photo/0005/2013-09-25/99LA1FC60B6P0005.jpg',
#   'image_id': '3cd32bef87ed98572bac868418521852ac3f6a70.jpg',
#   'caption': ['一个双臂抬起的运动员跪在绿茵茵的球场上',
#    '一个抬着双臂的运动员跪在足球场上',
#    '一个双手握拳的男人跪在绿茵茵的足球场上',
#    '一个抬起双手的男人跪在碧绿的球场上',
#    '一个双手握拳的运动员跪在平坦的运动场上']},
#  {'url': 'http://img.hexun.com/2011-06-09/130363655.jpg',
#   'image_id': 'fb36d921dcd9184bdd4659864fe7f3cff47accf5.jpg',
#   'caption': ['房间里一个右手放在嘴角的女人和一个戴着眼镜的男人在研究仪器',
#    '一个披着长发的女人和一个戴着眼镜的男人站在室内的桌子旁',
#    '室内有一个戴着眼镜的男人在向一个抬起右手的女人展示东西',
#    '房间里有一个左手放在盒子上的男人在给一个右手食指放在嘴边的女人展示东西',
#    '一个右手放在嘴边的女人和一个戴着眼镜的男人站在房间里']}]

# %%
validation_annotations_dict = {x['image_id']: x['caption'][0] for x in validation_annotations}

# %%
img_paths_basenames = [os.path.basename(x) for x in img_paths]
img_captions = [validation_annotations_dict[x] for x in img_paths_basenames]

# %%
Image.open(img_paths[0])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=550x668>

# %%
img_captions[0]
# Out:
# '一个穿着裙子的女孩双手拿着东西站在宽阔的草地上'

# %% [markdown]
# # 加载CLIP模型

# %%
from PIL import Image
import requests
from transformers import ChineseCLIPProcessor, ChineseCLIPModel
import torch

model = ChineseCLIPModel.from_pretrained("./model/chinese-clip-vit-base-patch16") # 中文clip模型
processor = ChineseCLIPProcessor.from_pretrained("./model/chinese-clip-vit-base-patch16") # 预处理
# Out:
# ---------------------------------------------------------------------------
# HFValidationError                         Traceback (most recent call last)
# File D:\soft\miniconda3\envs\py312\Lib\site-packages\transformers\utils\hub.py:478, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     476 if len(full_filenames) == 1:
#     477     # This is slightly better for only 1 file
# --> 478     hf_hub_download(
#     479         path_or_repo_id,
#     480         filenames[0],
#     481         subfolder=None if len(subfolder) == 0 else subfolder,
#     482         repo_type=repo_type,
#     483         revision=revision,
#     484         cache_dir=cache_dir,
#     485         user_agent=user_agent,
#     486         force_download=force_download,
#     487         proxies=proxies,
#     488         resume_download=resume_download,
#     489         token=token,
#     490         local_files_only=local_files_only,
#     491     )
#     492 else:
#
# File D:\soft\miniconda3\envs\py312\Lib\site-packages\huggingface_hub\utils\_validators.py:106, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     105 if arg_name in ["repo_id", "from_id", "to_id"]:
# --> 106     validate_repo_id(arg_value)
#     108 elif arg_name == "token" and arg_value is not None:
#
# File D:\soft\miniconda3\envs\py312\Lib\site-packages\huggingface_hub\utils\_validators.py:154, in validate_repo_id(repo_id)
#     153 if repo_id.count("/") > 1:
# --> 154     raise HFValidationError(
#     155         "Repo id must be in the form 'repo_name' or 'namespace/repo_name':"
#     156         f" '{repo_id}'. Use `repo_type` argument if needed."
#     157     )
#     159 if not REPO_ID_REGEX.match(repo_id):
#
# HFValidationError: Repo id must be in the form 'repo_name' or 'namespace/repo_name': './model/chinese-clip-vit-base-patch16'. Use `repo_type` argument if needed.
#
# During handling of the above exception, another exception occurred:
#
# HFValidationError                         Traceback (most recent call last)
# Cell In[7], line 6
#       3 from transformers import ChineseCLIPProcessor, ChineseCLIPModel
#       4 import torch
# ----> 6 model = ChineseCLIPModel.from_pretrained("./model/chinese-clip-vit-base-patch16") # 中文clip模型
#       7 processor = ChineseCLIPProcessor.from_pretrained("./model/chinese-clip-vit-base-patch16")
#
# File D:\soft\miniconda3\envs\py312\Lib\site-packages\transformers\modeling_utils.py:288, in restore_default_dtype.<locals>._wrapper(*args, **kwargs)
#     286 old_dtype = torch.get_default_dtype()
#     287 try:
# --> 288     return func(*args, **kwargs)
#     289 finally:
#     290     torch.set_default_dtype(old_dtype)
#
# File D:\soft\miniconda3\envs\py312\Lib\site-packages\transformers\modeling_utils.py:4863, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, *model_args, **kwargs)
#    4860 if commit_hash is None:
#    4861     if not isinstance(config, PretrainedConfig):
#    4862         # We make a call to the config file first (which may be absent) to get the commit hash as soon as possible
# -> 4863         resolved_config_file = cached_file(
#    4864             pretrained_model_name_or_path,
#    4865             CONFIG_NAME,
#    4866             cache_dir=cache_dir,
#    4867             force_download=force_download,
#    4868             proxies=proxies,
#    4869             local_files_only=local_files_only,
#    4870             token=token,
#    4871             revision=revision,
#    4872             subfolder=subfolder,
#    4873             _raise_exceptions_for_gated_repo=False,
#    4874             _raise_exceptions_for_missing_entries=False,
#    4875             _raise_exceptions_for_connection_errors=False,
#    4876         )
#    4877         commit_hash = extract_commit_hash(resolved_config_file, commit_hash)
#    4878     else:
#
# File D:\soft\miniconda3\envs\py312\Lib\site-packages\transformers\utils\hub.py:321, in cached_file(path_or_repo_id, filename, **kwargs)
#     263 def cached_file(
#     264     path_or_repo_id: Union[str, os.PathLike],
#     265     filename: str,
#     266     **kwargs,
#     267 ) -> Optional[str]:
#     268     """
#     269     Tries to locate a file in a local folder and repo, downloads and cache it if necessary.
#     270
#    (...)    319     ```
#     320     """
# --> 321     file = cached_files(path_or_repo_id=path_or_repo_id, filenames=[filename], **kwargs)
#     322     file = file[0] if file is not None else file
#     323     return file
#
# File D:\soft\miniconda3\envs\py312\Lib\site-packages\transformers\utils\hub.py:531, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     523     raise OSError(
#     524         f"PermissionError at {e.filename} when downloading {path_or_repo_id}. "
#     525         "Check cache directory permissions. Common causes: 1) another user is downloading the same model (please wait); "
#     526         "2) a previous download was canceled and the lock file needs manual removal."
#     527     ) from e
#     529 # Now we try to recover if we can find all files correctly in the cache
#     530 resolved_files = [
# --> 531     _get_cache_file_to_return(path_or_repo_id, filename, cache_dir, revision, repo_type)
#     532     for filename in full_filenames
#     533 ]
#     534 if all(file is not None for file in resolved_files):
#     535     return resolved_files
#
# File D:\soft\miniconda3\envs\py312\Lib\site-packages\transformers\utils\hub.py:144, in _get_cache_file_to_return(path_or_repo_id, full_filename, cache_dir, revision, repo_type)
#     136 def _get_cache_file_to_return(
#     137     path_or_repo_id: str,
#     138     full_filename: str,
#    (...)    142 ):
#     143     # We try to see if we have a cached version (not up to date):
# --> 144     resolved_file = try_to_load_from_cache(
#     145         path_or_repo_id, full_filename, cache_dir=cache_dir, revision=revision, repo_type=repo_type
#     146     )
#     147     if resolved_file is not None and resolved_file != _CACHED_NO_EXIST:
#     148         return resolved_file
#
# File D:\soft\miniconda3\envs\py312\Lib\site-packages\huggingface_hub\utils\_validators.py:106, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     101 for arg_name, arg_value in chain(
#     102     zip(signature.parameters, args),  # Args values
#     103     kwargs.items(),  # Kwargs values
#     104 ):
#     105     if arg_name in ["repo_id", "from_id", "to_id"]:
# --> 106         validate_repo_id(arg_value)
#     108     elif arg_name == "token" and arg_value is not None:
#     109         has_token = True
#
# File D:\soft\miniconda3\envs\py312\Lib\site-packages\huggingface_hub\utils\_validators.py:154, in validate_repo_id(repo_id)
#     151     raise HFValidationError(f"Repo id must be a string, not {type(repo_id)}: '{repo_id}'.")
#     153 if repo_id.count("/") > 1:
# --> 154     raise HFValidationError(
#     155         "Repo id must be in the form 'repo_name' or 'namespace/repo_name':"
#     156         f" '{repo_id}'. Use `repo_type` argument if needed."
#     157     )
#     159 if not REPO_ID_REGEX.match(repo_id):
#     160     raise HFValidationError(
#     161         "Repo id must use alphanumeric chars or '-', '_', '.', '--' and '..' are"
#     162         " forbidden, '-' and '.' cannot start or end the name, max length is 96:"
#     163         f" '{repo_id}'."
#     164     )
#
# HFValidationError: Repo id must be in the form 'repo_name' or 'namespace/repo_name': './model/chinese-clip-vit-base-patch16'. Use `repo_type` argument if needed.

# %% [markdown]
# # 图像编码

# %%
img_image_feat = []

batch_size = 20
for idx in tqdm_notebook(range(len(img_captions) // batch_size + 1)):
    imgs = [ Image.open(path) for path in img_paths[idx*batch_size: (idx+1)*batch_size] ]
    
    if len(imgs) == 0:
        break
    
    inputs = processor(images=imgs, return_tensors="pt")
    with torch.no_grad():
        image_features = model.get_image_features(**inputs)
        image_features = image_features.data.numpy()
        img_image_feat.append(image_features)

    break
        
img_image_feat = np.vstack(img_image_feat)
img_image_feat = normalize(img_image_feat)

# %%
img_image_feat.shape # 20张图片 512 维度

# %% [markdown]
# # 文本编码

# %%
img_texts_feat = []

batch_size = 20
for idx in tqdm_notebook(range(len(img_captions) // batch_size + 1)):
    texts = [ text for text in img_captions[idx*batch_size: (idx+1)*batch_size] ]

    if len(texts) == 0:
        break
    
    inputs = processor(text=texts, return_tensors="pt", padding=True)

    with torch.no_grad():
        text_features = model.get_text_features(**inputs)
        text_features = text_features.data.numpy()
        img_texts_feat.append(text_features)
    break
        
img_texts_feat = np.vstack(img_texts_feat)
img_texts_feat = normalize(img_texts_feat)

# %%
img_texts_feat.shape

# %% [markdown]
# # 尝试1：相似度计算

# %%
query_idx = 250

sim_result = np.dot(img_texts_feat[query_idx], img_image_feat.T) # 矩阵计算
sim_idx = sim_result.argsort()[::-1][1:4]

# %%
print('输入文本: ', img_captions[query_idx])

plt.figure(figsize=(10, 5))
plt.subplot(131)
plt.imshow(Image.open(img_paths[sim_idx[0]]))
plt.xticks([]); plt.yticks([])

plt.subplot(132)
plt.imshow(Image.open(img_paths[sim_idx[1]]))
plt.xticks([]); plt.yticks([])

plt.subplot(133)
plt.imshow(Image.open(img_paths[sim_idx[2]]))
plt.xticks([]); plt.yticks([])

# %%
query_idx = 250

sim_result = np.dot(img_image_feat[query_idx], img_texts_feat.T)
sim_idx = sim_result.argsort()[::-1][1:4]

# %%
plt.imshow(Image.open(img_paths[query_idx]))

print('文本识别结果: ', [img_captions[x] for x in sim_idx])

# %% [markdown]
# # 文本标签编码

# %%
import jieba

# %%
jieba.lcut('今天天气很好，心情也很好。')

# %%
jieba.lcut(img_captions[0])

# %%
img_captions2words = [jieba.lcut(x) for x in img_captions]
img_captions2words = sum(img_captions2words, [])

# %%
img_captions2words[:10]

# %%
img_captions2words = [x for x in img_captions2words if len(x) > 1]
img_captions2words = list(set(img_captions2words))

# %%
img_captions2words[:10]

# %%
img_texts_feat = []

batch_size = 20
for idx in tqdm_notebook(range(len(img_captions2words) // batch_size + 1)):
    texts = [ text for text in img_captions2words[idx*batch_size: (idx+1)*batch_size] ]

    if len(texts) == 0:
        break
    
    inputs = processor(text=texts, return_tensors="pt", padding=True)

    with torch.no_grad():
        text_features = model.get_text_features(**inputs)
        text_features = text_features.data.numpy()
        img_texts_feat.append(text_features)
        
img_texts_feat = np.vstack(img_texts_feat)
img_texts_feat = normalize(img_texts_feat)

# %% [markdown]
# # 尝试2：标签相似度计算

# %%
query_idx = 120

sim_result = np.dot(img_image_feat[query_idx], img_texts_feat.T)
sim_idx = sim_result.argsort()[::-1][1:7]

# %%
plt.imshow(Image.open(img_paths[query_idx]))

print('文本识别结果: ', [img_captions2words[x] for x in sim_idx])

# %%
# !modelscope download --model AI-ModelScope/chinese-clip-vit-base-patch16 --local_dir ./model/chinese-clip-vit-base-patch16
